# %%
exp=['January',2200,'February' , 2350,'March', 2600,'April' ,2130, 'May', 2190]
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
months=['January','February' , 'March','April' , 'May']
exp=[2200,2350,2600,2130,2190]

# %%
report=[months,exp]

# %%
print(months[1],'extra spend = ', exp[1]-exp[0])

# %%
print('Total Expence for first quarter = ', exp[0]+exp[1]+exp[2])

# %%
for i in range(len(exp)):
               if exp[i]==2000:
                    print(months[i])

# %%
insert 1980

# %%
from pandas_datareader.data import DataReader
from datetime import datetime
tech_list = ['AAPL', 'GOOG', 'MSFT', 'AMZN']
end = datetime.now()
start = datetime(end.year - 1, end.month, end.day,end.hour,end.minute,end.second)

for stock in tech_list:   
    # Set DataFrame as the Stock Ticker
    aapl = data.DataReader(stock,start='2015-1-1', end='2015-12-31', data_source='yahoo')
#     print(aapl)
company_name = ["APPLE", "GOOG" , "MICROSOFT", "AMAZON"]
company_list = [AAPL, GOOG, MSFT, AMZN]
for company, com_name in zip(company_list, company_name):
    company["company_name"] = com_name
amd=zip(company_list, company_name)
list(amd)
# Out:
# [(                  High         Low        Open       Close       Volume  \
#   Date
#   2020-03-13   69.980003   63.237499   66.222504   69.492500  370732000.0
#   2020-03-16   64.769997   60.000000   60.487499   60.552502  322423600.0
#   2020-03-17   64.402496   59.599998   61.877499   63.215000  324056000.0
#   2020-03-18   62.500000   59.279999   59.942501   61.667500  300233600.0
#   2020-03-19   63.209999   60.652500   61.847500   61.195000  271857200.0
#   ...                ...         ...         ...         ...          ...
#   2021-03-08  121.000000  116.209999  120.930000  116.360001  153918600.0
#   2021-03-09  122.059998  118.790001  119.029999  121.089996  129159600.0
#   2021-03-10  122.169998  119.449997  121.690002  119.980003  111760400.0
#   2021-03-11  123.209999  121.260002  122.540001  121.959999  102753600.0
#   2021-03-12  121.169998  119.160004  120.400002  121.029999   87963400.0
#
#                Adj Close company_name
#   Date
# ...

# %%
import yfinance as yf
import numpy as np
import pandas as pd

import datetime as datetime
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_S&P_500_companies')[0]

# %%
tickers=df.Symbol.to_list()

# %%
len(tickers)
# Out:
# 505

# %%
df2=yf.download(tickers,start='2010-12-31',end='2021-03-22')
# Out:
# [*********************100%***********************]  505 of 505 completed
#
# 2 Failed downloads:
# - BRK.B: No data found, symbol may be delisted
# - BF.B: No data found for this date range, symbol may be delisted

# %%
prices=df2['Adj Close']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f4c4e2840b6e> in <module>
# ----> 1 prices=df2['Adj Close']
#
# NameError: name 'df2' is not defined

# %%
prices
# Out:
#                      A        AAL         AAP        AAPL        ABBV  \
# Date
# 2010-12-30         NaN        NaN         NaN         NaN         NaN
# 2010-12-31   27.194845   9.436843   64.257729    9.922909         NaN
# 2011-01-03   27.490225  10.040195   63.626289   10.138556         NaN
# 2011-01-04   27.234232  10.011914   60.459553   10.191467         NaN
# 2011-01-05   27.175158  10.464431   60.537254   10.274836         NaN
# ...                ...        ...         ...         ...         ...
# 2021-03-15  124.040001  25.170000  181.440369  123.989998  110.260002
# 2021-03-16  123.000000  24.469999  178.863907  125.570000  110.839996
# 2021-03-17  122.519997  25.160000  181.710007  124.760002  105.040001
# 2021-03-18  122.589996  24.700001  183.729996  120.529999  103.769997
# 2021-03-19  122.690002  24.969999  186.000000  119.989998  103.419998
#
#                    ABC        ABMD         ABT         ACN        ADBE  ...  \
# ...

# %%
prices.index=pd.to_datetime(prices.index)

# %%
prices.dropna()
# Out:
# Empty DataFrame
# Columns: [A, AAL, AAP, AAPL, ABBV, ABC, ABMD, ABT, ACN, ADBE, ADI, ADM, ADP, ADSK, AEE, AEP, AES, AFL, AIG, AIZ, AJG, AKAM, ALB, ALGN, ALK, ALL, ALLE, ALXN, AMAT, AMCR, AMD, AME, AMGN, AMP, AMT, AMZN, ANET, ANSS, ANTM, AON, AOS, APA, APD, APH, APTV, ARE, ATO, ATVI, AVB, AVGO, AVY, AWK, AXP, AZO, BA, BAC, BAX, BBY, BDX, BEN, BF.B, BIIB, BIO, BK, BKNG, BKR, BLK, BLL, BMY, BR, BRK.B, BSX, BWA, BXP, C, CAG, CAH, CARR, CAT, CB, CBOE, CBRE, CCI, CCL, CDNS, CDW, CE, CERN, CF, CFG, CHD, CHRW, CHTR, CI, CINF, CL, CLX, CMA, CMCSA, CME, ...]
# Index: []
#
# [0 rows x 505 columns]

# %%
prices
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-690d0bab5559> in <module>
# ----> 1 prices
#
# NameError: name 'prices' is not defined
